# %% [markdown]
# Importing pandas

# %%
import datetime
print(f"Last updated: {datetime.datetime.now()}")
# Out:
# Last updated: 2026-09-09 14:49:56.388287

# %% [markdown]
# importing pandas

# %%
import pandas as pd

# Print the version
print(f"pandas version: {pd.__version__}")
# Out:
# pandas version: 3.0.5

# %% [markdown]
# Datatypes

# %%
# Creating a series of car types
cars = pd.Series(["BMW", "Toyota", "Honda"])
cars
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: str

# %%
# Creating a series of colours
colours = pd.Series(["Blue", "Red", "White"])
colours
# Out:
# 0     Blue
# 1      Red
# 2    White
# dtype: str

# %%
# Creating a DataFrame of cars and colours
car_data = pd.DataFrame({"Car type": cars, 
                         "Colour": colours})
car_data
# Out:
#   Car type Colour
# 0      BMW   Blue
# 1   Toyota    Red
# 2    Honda  White

# %% [markdown]
# Practice of bike data

# %%
bikes=pd.Series(["Yamaha", "Suzuki", "Kawasaki"])
bikes
# Out:
# 0      Yamaha
# 1      Suzuki
# 2    Kawasaki
# dtype: str

# %%
Price=pd.Series([1000, 2000, 3000])
Price
# Out:
# 0    1000
# 1    2000
# 2    3000
# dtype: int64

# %%
bike_data=pd.DataFrame({"Bike_types":bikes,
                        "Price":Price})
bike_data
# Out:
#   Bike_types  Price
# 0     Yamaha   1000
# 1     Suzuki   2000
# 2   Kawasaki   3000

# %%
# Example solution

# Make a Series of different foods
foods = pd.Series(["Almond butter", "Eggs", "Avocado"])

# Make a Series of different dollar values 
prices = pd.Series([9, 6, 2])

# Combine your Series of foods and dollar values into a DataFrame
food_data = pd.DataFrame({"Foods": foods,
                          "Price": prices})

food_data
# Out:
#            Foods  Price
# 0  Almond butter      9
# 1           Eggs      6
# 2        Avocado      2

# %% [markdown]
#  Importing data

# %%
# Import car sales data
car_sales = pd.read_csv("/Users/shahjalalmd/Desktop/pandas/pandas-sj-data-science/car_sales.csv") # takes a filename as string as input

car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Import the car sales data and save it to df

# Read from a CSV file (stored on our local computer)
df = pd.read_csv("/Users/shahjalalmd/Desktop/pandas/pandas-sj-data-science/car_sales.csv")


df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# Exporting data

# %%
# Export the car sales DataFrame to csv
car_sales.to_csv("/Users/shahjalalmd/Desktop/pandas/pandas-sj-data-science/exported_car_sales.csv")

# %% [markdown]
# Example solution

# %%
# Importing heart-disease.csv
patient_data = pd.read_csv("/Users/shahjalalmd/Desktop/pandas/pandas-sj-data-science/heart.csv")
patient_data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...
